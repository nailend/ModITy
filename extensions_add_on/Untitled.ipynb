# %%
import pandas as pd

# %%
df_transfer = pd.read_csv("../Input/Transfertabelle.csv", sep=';', decimal=',')

# %%
df_transfer.NUTS3
# Out:
# 0      DE22A
# 1      DE21N
# 2      DE221
# 3      DE219
# 4      DE21I
#        ...
# 396    DEB17
# 397    DEA5B
# 398    DEA57
# 399    DEF09
# 400    DEG0B
# Name: NUTS3, Length: 401, dtype: object

# %%
new_dict =dict.fromkeys(df_transfer.NUTS3, False)

# %%
choice = dict.fromkeys(df_transfer.NUTS3[:4], True)

# %%
choice
# Out:
# {'DE22A': True, 'DE21N': True, 'DE221': True, 'DE219': True}

# %%
new_dict.update(choice)

# %%
new_dict
# Out:
# {'DE22A': True,
#  'DE21N': True,
#  'DE221': True,
#  'DE219': True,
#  'DE21I': False,
#  'DE21J': False,
#  'DE21K': False,
#  'DE21L': False,
#  'DE146': False,
#  'DE119': False,
#  'DE712': False,
#  'DE713': False,
#  'DE715': False,
#  'DE27E': False,
#  'DE269': False,
#  'DE242': False,
#  'DE263': False,
#  'DE251': False,
#  'DE252': False,
#  'DE253': False,
#  'DE949': False,
#  'DE936': False,
#  'DE938': False,
#  'DE929': False,
#  'DE945': False,
#  'DEA11': False,
#  'DE724': False,
#  'DE735': False,
#  'DE71D': False,
#  'DE737': False,
#  'DE911': False,
#  'DE80K': False,
#  'DE80L': False,
#  'DED2D': False,
#  'DED43': False,
#  'DEB13': False,
#  'DEB22': False,
#  'DEA2D': False,
#  'DEA32': False,
#  'DEA33': False,
#  'DEB25': False,
#  'DEB31': False,
#  'DEB1A': False,
#  'DEB1B': False,
#  'DEG01': False,
#  'DEF01': False,
#  'DE21M': False,
#  'DE216': False,
#  'DE223': False,
#  'DE131': False,
#  'DE11C': False,
#  'DE121': False,
# ...
